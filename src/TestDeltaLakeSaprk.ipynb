# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

df = spark.range(10)
df.write.format("delta").mode("overwrite").save("/opt/warehouse/demo_table")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/24 06:17:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pyspark.sql import SparkSession
# ----> 3 spark = SparkSession.builder.getOrCreate()
#       5 df = spark.range(10)
#       6 df.write.format("delta").mode("overwrite").save("/opt/warehouse/demo_table")
#
# File /usr/local/lib/python3.10/dist-packages/pyspark/sql/session.py:500, in SparkSession.Builder.getOrCreate(self)
#     497     sc = SparkContext.getOrCreate(sparkConf)
# ...

# %%
spark.read.format("delta").load("/opt/warehouse/demo_table").show()
